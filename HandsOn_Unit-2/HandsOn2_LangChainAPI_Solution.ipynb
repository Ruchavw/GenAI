# %% [markdown]
# Name: Rucha Vikrant Wadhavankar
#
# SRN: PES2UG23CS496

# %%
# %pip install python-dotenv --upgrade --quiet langchain langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.5/500.5 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 10.2 MB/s eta 0:00:00

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API key: ")
# Out:
# Enter your Google API key: ··········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm_focused = ChatGoogleGenerativeAI(model = "gemini-2.5-flash", temperature=0.0)

llm_creative = ChatGoogleGenerativeAI(model = "gemini-2.5-flash", temperature=1.0)

# %%
prompt = "Define the word 'Idea' in one sentence."

print("--- FOCUSED (Temp=0) ---")
print(f"Run 1: {llm_focused.invoke(prompt).content}")
print(f"Run 2: {llm_focused.invoke(prompt).content}")
# Out:
# --- FOCUSED (Temp=0) ---
# Run 1: An idea is a thought, concept, or suggestion that is formed or exists in the mind.
# Run 2: An idea is a thought, concept, or mental image formed in the mind.

# %%
print("\n--- CREATIVE (Temp=1) ---")
print(f"Run 1: {llm_creative.invoke(prompt).content}")
print(f"Run 2: {llm_creative.invoke(prompt).content}")
# Out:
# --- CREATIVE (Temp=1) ---
# Run 1: An idea is a mental conception, impression, or thought that can serve as the basis for understanding, action, or creation.
# Run 2: An idea is a thought, concept, or mental impression formed in the mind.

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API key: ")

llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages =[
    SystemMessage(content="You are a very sweet girl near my house. Your name is Riya."),
    HumanMessage(content="What is the capital of Fraance?")
    ]
response = llm.invoke(messages)
print(response.content)
# Out:
# Oh, that's an easy one! The capital of France is **Paris**! 😊

# %%
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages([
    ("system", "You are a translator. Translate {input_language} to {output_language}."),
    ("human", "{text}")
])

print(f"Required variables: {template.input_variables}")
# Out:
# Required variables: ['input_language', 'output_language', 'text']

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

raw_msg = llm.invoke("Hi, I am Rucha")
print(f"Raw Type: {type(raw_msg)}")

clean_text = parser.invoke(raw_msg)
print(f"Parsed Type: {type(clean_text)}")
print(f"Content: {clean_text}")
# Out:
# Raw Type: <class 'langchain_core.messages.ai.AIMessage'>
# Parsed Type: <class 'langchain_core.messages.base.TextAccessor'>
# Content: Hello Rucha! It's nice to meet you.
#
# How can I assist you today?

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API key: ")

llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")
template = ChatPromptTemplate.from_template("Tell me a fun fact about {topic}.")
parser = StrOutputParser()

# %%
prompt_value = template.invoke({"topic":"Cats"})
response_obj = llm.invoke(prompt_value)
final_text = parser.invoke(response_obj)
print(final_text)
# Out:
# Here's a fun one:
#
# Cats don't actually meow at other cats! They primarily meow to communicate with **humans**.
#
# When cats interact with each other, they use a different set of vocalizations like hisses, growls, and chirps. The "meow" seems to be a special language they developed just for us!

# %%
chain = template | llm | parser
print(chain.invoke({"topic":"Dogs"}))
# Out:
# Here's a fun one:
#
# **Did you know a dog's nose print is as unique as a human's fingerprint?**
#
# No two dogs have the exact same pattern of ridges and indentations on their noses, making their "nose print" a one-of-a-kind identifier!

# %% [markdown]
# #Assignment

# %%
movie_template = ChatPromptTemplate.from_template(
    "For the movie '{movie_name}', what was its release year, and how many years ago was that based on the current year? Please respond in a single sentence like: 'The movie [Movie Name] was released in [Year], which was [Number] years ago.'"
)

movie_chain = movie_template | llm | parser

print(movie_chain.invoke({"movie_name": "Dhurandhar"}))
print(movie_chain.invoke({"movie_name": "Cinderella"}))
# Out:
# The movie Dhurandhar was released in 2022, which was 2 years ago.
# The movie Cinderella was released in 1950, which was 74 years ago.
